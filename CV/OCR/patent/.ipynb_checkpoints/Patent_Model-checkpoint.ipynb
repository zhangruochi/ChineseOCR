# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
import torch.utils as utils
import torchvision
from torchsummary import summary

from albumentations.pytorch import ToTensor
import albumentations as A
from tqdm import tqdm
import random
import numpy as np
import cv2
from collections import OrderedDict

from PIL import Image, ImageDraw, ImageFont

from matplotlib import pyplot as plt
import time
import os

import pickle as pkl
from pathlib import Path

# %% [markdown]
# ## Hyper-parameters

# %%
BATCH_SIZE = 16
NUM_EPOCHS = 20
LEARNING_RATE = 0.0001
RANDOM_SEED = 42

DEVICE = torch.device("cuda: 0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Helpers

# %%
def show_batch(x,y,shape = None):
    """
    input: 
        x(Tensor[num_images, rows, columns]): images tensor
        y(array): labels
        shape(tuple): (rows,col) 
    output:
        grid of smaple images
    """

    if not shape:
        shape = (int(x.shape[0]**0.5), int(x.shape[0]**0.5))

    fig, axs = plt.subplots(nrows= shape[0], ncols=shape[1], figsize = (12,8))
    index = 0
    for row in axs:
        for ax in row:
            ax.imshow(x[index])
            ax.set_xlabel(y[index], )
            index+=1
    # plt.subplots_adjust(wspace = 0.2, hspace = 0.5) 
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ## Dataset

# %%
root = Path("total_pic_patent")
char_set = set()
for direc in root.glob("*"):
    if direc.is_dir():
        for file in direc.glob("*.png"):
            if file.name != "origin.png":
                char = file.name[0]
                char_set.add(char)

len(char_set)
# Out:
# 2470

# %%
"".join(char_set)
# Out:
# '茬她亿公西匠倾悲锌附翰脐类曰昼亚硼冻温嘿鸽塑村禄逼集墓啮脾诣柒篷活砷祭栅吴井凿淹痉舜炬君旱钳悬阮氯垣臻又搽诲冶灌淑浮猛债搔评浙示紧缩怔斗拓羔殆恼终召墩佛锚冕崔退嗽簇巫谁给刺饥幼条策旺根幸纲角谗捕姬视讶沃介贮馒续谎呈滴喝忌歇捌柬峭莱虾铺炼蝎进烯搜让重漆隧词两郁娶龚铲献肆曝藩葛帘嚣盘以姓份耽首议钦干瞠生青沧浦氨代燎庭躲逆遏膘呼嘉至胶成孩肮缆责孕乙皆蔽婚慑爱促霖迄欲丧砚铁则煌订讼古贼招浇辜瑰酱眶袒暑揖夫斋辆俭枢亡桅贰钝试渤闽学袜避闷吹氧分崇锣初敢宦喊绑硫枉但裁水萧玩忙技鳞骋筐侩破虱步霄屯曳佣倘秽态版鹅浩鸟茨段钉弥季盒荆洁丹戳仍挪郎月攒谰匡僳午鲁沼陶概噶吏阶鸯靛非冯肇倡倒扩溜帧靖充影菌后朋搀观瘫怀签缴暗度琉烧铀网钥禾孝边渭墨彭铜港胞悍瀑恰悯湛堑摊醋拳蜡锦管丁稻叔春剩淖憾率绕规售驹瘤泅署缠搅蝉咸萝种发惩麓零叹寸蚂譬侗抵传狰詹斩滞外满关熏质时汾潍淬贩贡驳瞧禹馋任盾箔檬衔踞兵篓什镊诱徽滩劲扫悦疑诬穴断益匪荐加蝶侠毡领瘪丑汀野翠真米呢或务朽悠直溯梁决擅教痘粳岸便枫靡恕弗舰芋懒诸贝嚼舱娜拯觉翁宫冰低街蹈棱酶摇卡熙毛木嘘恩恳光庐奴咯差武阀陈绅数狂律赖诞缅宿典嫩横聂馏黍葡拖相胆恃浓量像留胃仙卯押斡眉舆触并跨晕憎副土晋伦永涪讨穆卢洽冠扦符雀炔崖寐椭炎菠饼虎被越颂琶豺般势汉税蛋苔呵艺百默啊嚷秆歌线洲平艳鸡痰酞累残怂埔兄尽窄露嗡汛萨彝雕讽浴剂忠连屑糯诚诀框它正呐值腆蚀归绸瞥狮鄙垢磋柱罩臃拱颐忘蜀妥嘲酉择娩谤误朗衣赐吃障劝葫伐辣拧洋贫霓鸭丸掸回联软腮颈镭吱饲功舒协蓖掇世蛀濒疆陀巍循达帝硕汪陷莉剁涯踊蚤极敛全岿划日痊狡寇亲侄拦赡沁励冤疫券蚜娃跪薪业谜疽帚鼠臀苹流皱盯釉攘凳契圭寨父跋我症幢拎柯腹晤赁靶殉拭吠贱槐赦战兴必惨价泞撇既钾锗限潜拉取践隅拨返十遇湃岔攀八腾泄会肃楔邑挽买雹纠辑蛾疥尉调孤颖砾钢本溢鞠涉奉诊损皋列冬牢嵌诫垫指梢幌奖傣吐杰霞据凤谚里绊甥胸壁垃要挎美酚湍寂室禅甩堰窝颗捆珐镜爬敬辫督市剔肝遗洼丽吗溺担埠煮怜旁皮秃掩涟老营涣纷也础墙咙淮究钩锑陆锭睛级夺受论倍爹呀造檀蛆娥辞籍都杠舅致猜痒淤谈杆踌赊撅持酒另堵讯钱醛咏莹壤卉硷曲锰怠搬砧秧哨德效站拗叮蛛邯瓮邢窍驾铸即唐千筛蒙镑崩娇酪梗搪骇舞闹燃诗具弯范咕狈复赋尚沙鞭堂朴蕾翟尿脱官巡伶铆浆跃刊待嫉辐离衅风抉原祷海勋床锡衷燕扔厦讹惆推高袄盗局争常殖衡仕盲叶赂嚏鲸祁菱七蚁鳖眨微考巢曙巴上桃沾吝享妖蒜三坑褪戍灵实逛柠毕痢番酋芽虑念吉钡桐辗叙助腿儡州队察瞳团见盐降去训封措躬挞简滔猩渺伍坏焰从商涅之尖疮黄泊遍丙临偿殿卧题侥咋问摘礁窃柴锯芯匆汲翘雅伤神锻孺捎革逐哥骗清赫扶锐征脸坎黑淋骂刑廖炸军翻酗人国惊瘟理星冉滤鸵癸穷垮函砰前屎昂攻萍讳涡窟坞遣投胜旗宴矽畦厕难媳抛稿森御榔冀饶渗仇核眷茹磨源靠描捏坟朱俊狄亥忆莆覆精遁涵内错霜那肥折撮适蘑罚盔灭谍悟车梭逢痞仁趴顽苦旭伏寒舵远粗舔烩刘跑啥挚捣曹合库茂链口写蓑书帐们放裔烛境蛮枷椽仪绝泡倔译趾许监佰朔险太刷渐沤甜李炭莎除追糊滚匙龄器汐姐耕敦职峙胚翼兆秘藕糟削霹鹃凌候胎粉邦玛萤惯玻天姚愤顶排绚枪漂基酣援喂冲拜怨兑窗慰钵刮旋膜葬抒蠢云抠碑渊申偶憋姑钎经痴俘演婆减性铃记栈焙梧慧渴撤骚控妓鞍炊亨躯泽否趣蜂葱欢坛击鼎轴懦插刚喷轮豌快心添金托空惋畅翅点雁能惹键咆盼肚帆谱赔柑窒搐混者席虽硒锄糙孙烁害伸绣囚输碰蹿酷栓哟殷勾挂酵咽哉秉秸氛媒肾抖衫克伊谬揣乘袱骑趟哭胺堡急甚粒臣撑徒寺颁嗅畏擞咒崎桔幂应画阔抨韩严谋揽栀头求的堕诉掠夜习耙眠欣群饺驭柳凉方帛苏噎蕴淡惜蘸在娘案岗碍串魄哪迟店袁党苟家末少拂吨江短改爵界历诺因篮癌不蔼泣躺坝甄湘隔厌殴痛剐硅贾犁先唉掷霉芦宵味魁婪扮铱灰蒲堤枯峨静淫讥瞻阎烙怕选挡丛佯糕剃奠帽读晚澳禁交望挛握桥圆锁汞惭额设怒烹易绿薯囱乃捡狸净敲四敞雷序贷素瓣绷坊鸳纳讫端货停缚蜕磁矛命航樟杖矾妈系铬楞象你嘻貌芭绪才榜睫赎挟肠枣蝗赶聚培中牛撒誉叫捅创瞎络鳃妻煞震韭间入距艾熔旧芹妹同田跟陛汰撕枚吁犊激菏姨族郝芳京思房滨导筋墅探域批苛唆疡晃捍拄鸦艘项杜驴废耘目渔歉镀爽奄墟拴忿妨扯斯姥茅箭血畔话侦唇膛捻变地寄榨道惦址音辟跳撬母釜邓映派庶语焕索齿粹邀辊志玫肤盆惰氏骸特别妄门袭啸拐缝凑聋胀坪醇趋徐碌升钠躁冒雨逸际屿显碉邻荧刃孔鸣舌炙彪纽响迢巨氢恿爷喇咳扛胯柏菇愧钟肌掳园钨贸踢眩亭弟制希筷跺剧杀统炕雪隋扳肺沛息球围歹狐莫恢罕侍机虐摩酬杂酮迪藉耪苗夹寝酝跌共驰蔬隆确拒出氖眯截登款郸肘芍标铐整淌寡填婶河脉罢透裸然颇棉守呛愁粤丝涕苫蜘斜胁叛瓤琅漠皂萄馆爆凋括樊松腕陇甸呕稍叭狼配绎悉嘶骡验镁缔赴勃帖滦垯秒峡随卸布悔械热灯扰弘早瞩止就匈来揭浚披届只容徊踏履昭警页卵沥猾按渡腺华余体荒矮惮寓筒溪况此允疗氓牟毅瞅病眼擎谊认术忱努栽脯缎详冈速鹤哑缺救搞接娄戎毒珍埃闰囊找笨吭灿溃绞弓力鉴獭萎鼻虚宛寻苇坍琳处秦歪裕医畜拟录沪恭乎烫棘咎尺禽薄砍耍解搓肢柔式茵他知谩丢宏浪辕缮灶喉壹估沉苞溶役愉敖北斑牵修淆脓农蔡普印幽柜舍捐赢卞鹊屋颤顺摈褥彬磺裙吻摧袖马刽多沿尾胖驯凰腔社瞪骤些九雇戒锤谢纪笑乾邱树圃剖史咱肿程彻积弹杭芝亮睬搏济等需厨嫡腥笛抑磊狱馈铰篆溅含抚尹唁对频琼落游乒表钓玖酿毖困提株患档结蛹篱当五祟逗愿啪油蹦识窥送颊伙沽稚夯慈言泪悸赃贞藤莲淀僻掀粮偷湾消鬼织潮轰料硬勘孪贤蛤把暇惑蔑珊浑这碧澡彰耳轻坦帜小电删恍饮够慕嘎簿眺洪沦叼缸纬谨斥腰塌嘱格膀莽今嫁载藏巩虞固型矿互仟麻吓闻牙骏途绘奥颧票诛磐橙操吊付揩刻引巷晶绥蝇螟褂幕哩饭供节壕所比院茎嘛抢涸异烘庇新衙沮搂迎辱颜烂奋诵存备片阿凡刹忽暂揪期墒魂鲤蓄猝津陋而妙县孽明垒敏泉捶橡约偏植锨婴腊疵疏弃厄暖坷怎烤沸伴抄坯餐阐搭兽羊几银惠霍豫桶掏坤脆酸竞巾烷茸熊磷戊哎馁惟揉妇澄迂礼靳块王慢桂俯汤泥液涤逊淘痕凝辖向采呻骄趁熄肋竣昏较事翌_犯台宋聊预物假枕啡撩膨治挠场幻检扑败庆瓷保欺竿啦隘涝铭抡曼扒砌束烽形恐尘久俄抿碱兢吩潭沟信博扭涩某负户山渣庚谅胰踩码唤动汹箱例均乞擦艇占戈敷洞溉听腻割审甫邮耶貉兔蹭涨男朵奶僧府笋于哦感槛钧鄂周粥遮大豪祥工查掺煎智烟侯情单诧壬答虫斟遥凯恋吵硝毫缨垦隶恬毁运葵桑匿证深雍彦牧居痹仑次膏镶'

# %%
class PatentOCRTestDataset(Dataset):
      
    def __init__(self, root, char_set, transforms = None):

        self.root = root
        self.transforms = transforms    
        self.char_set = char_set
        
        
        self.char2index = {key:val for key,val in zip(char_set,range(len(char_set)))}
        self.index2char = {val:key for key,val in zip(char_set,range(len(char_set)))}
        
        self.samples = []
        self.labels = []
        
        for direc in root.glob("*"):
            if direc.is_dir():
                for file in direc.glob("*.png"):
                    if file.name != "origin.png":
                        self.samples.append(file)

        self.samples *= 5
        random.shuffle(self.samples)
        
        for p in self.samples:
            self.labels.append(self.char2index[p.name[0]])

    def __getitem__(self, index):

        img = self.samples[index]
        target = self.labels[index] 
        img = cv2.imread(str(img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.transforms(image = img)["image"]

        return img, torch.tensor(target)
    
    def __len__(self):
        return len(self.samples)

# %%
transforms = A.Compose([
                        A.Resize(36,36),
                        A.Rotate(60,interpolation = cv2.INTER_LINEAR),
                        A.CenterCrop(32,32),
                        A.HueSaturationValue(p=0.3),
                        A.RandomBrightnessContrast(p=0.3),
                        A.ToGray(p=0.3),
                        A.OpticalDistortion(distort_limit=0.03, p = 0.3),
                        A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
                        ToTensor()
                    ])

dataset = PatentOCRTestDataset(root,char_set,transforms = transforms)


train_length = int(len(dataset) * 0.9)
val_length = len(dataset) - train_length

train_dataset, val_dataset = utils.data.random_split(dataset,[train_length, val_length])

train_dataloader = DataLoader(dataset = train_dataset,
                             batch_size=BATCH_SIZE,
#                              num_workers=4,
                             shuffle=True)

val_dataloader = DataLoader(dataset = val_dataset,
                             batch_size=BATCH_SIZE,
#                              num_workers=4,
                             shuffle=False)

dataset_loader = {"train": train_dataloader, "val": val_dataloader}

if not os.path.exists("../models/patent_model_checkpoint"):
    os.makedirs("../models/patent_model_checkpoint")

with open("../models/patent_model_checkpoint/cache.pkl", "wb") as f:
    pkl.dump({"index2char": dataset.index2char},f)

# %%
image, target = next(iter(train_dataloader))

# %%
show_batch(image.permute([0,2,3,1]), target.numpy(), (4,4))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
"".join([dataset.index2char[item] for item in target.numpy()])[:16]
# Out:
# '淆旺鬼铺叫闻薄胚锤弘械壬搅父附匆'

# %% [markdown]
# ## Model

# %%
class Model(nn.Module):
    def __init__(self, n_classes):
        super(Model, self).__init__()
        
        self.head = torch.nn.Sequential(
            torch.nn.Conv2d(3,64,kernel_size=(1,1),stride=(1,1),padding=(0,0),bias=False),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(inplace=True)
        )
        
        base_model = torchvision.models.resnet34(pretrained=False)
        base_model_layers = list(base_model.children()) 
        
        self.body = torch.nn.Sequential(*base_model_layers[4:9])
        self.fc = torch.nn.Linear(in_features=512, out_features=n_classes, bias = True)
    
    
    def forward(self, x):
        x = self.head(x)
        x = self.body(x)
        x = x.view(-1, x.shape[1])
        logits = self.fc(x)
        probas = F.softmax(logits, dim = 1)
        return logits,probas
    
class PatentModel(nn.Module):
    def __init__(self, n_classes):
        super(PatentModel, self).__init__()
        
        self.upstream_model = Model(n_classes = 3755)
        checkpoint = torch.load("../models/ocr_pretrained_model_checkpoint/best_model.pt",map_location=DEVICE)
        self.upstream_model.load_state_dict(checkpoint["model_state_dict"])
        
        in_features = self.upstream_model.fc.in_features
        self.upstream_model.fc = torch.nn.Linear(in_features=in_features, out_features=n_classes, bias = True)

    def forward(self, x):
        logits,probas = self.upstream_model(x)
        return logits,probas

# %%
model = PatentModel(n_classes = len(char_set))
model = model.to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        patience=2,
        threshold=0.01,
        factor = 0.2,
        verbose=True,
        mode="max")

# %%
summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]             192
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#               ReLU-9           [-1, 64, 32, 32]               0
#        BasicBlock-10           [-1, 64, 32, 32]               0
#            Conv2d-11           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-12           [-1, 64, 32, 32]             128
#              ReLU-13           [-1, 64, 32, 32]               0
#            Conv2d-14           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-15           [-1, 64, 32, 32]             128
#              ReLU-16           [-1, 64, 32, 32]               0
#        BasicBlock-17           [-1, 64, 32, 32]               0
#            Conv2d-18           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-19           [-1, 64, 32, 32]             128
#              ReLU-20           [-1, 64, 32, 32]               0
#            Conv2d-21           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-22           [-1, 64, 32, 32]             128
#              ReLU-23           [-1, 64, 32, 32]               0
#        BasicBlock-24           [-1, 64, 32, 32]               0
#            Conv2d-25          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-26          [-1, 128, 16, 16]             256
#              ReLU-27          [-1, 128, 16, 16]               0
#            Conv2d-28          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-29          [-1, 128, 16, 16]             256
#            Conv2d-30          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-31          [-1, 128, 16, 16]             256
#              ReLU-32          [-1, 128, 16, 16]               0
#        BasicBlock-33          [-1, 128, 16, 16]               0
#            Conv2d-34          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-35          [-1, 128, 16, 16]             256
#              ReLU-36          [-1, 128, 16, 16]               0
#            Conv2d-37          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#              ReLU-39          [-1, 128, 16, 16]               0
#        BasicBlock-40          [-1, 128, 16, 16]               0
#            Conv2d-41          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-42          [-1, 128, 16, 16]             256
#              ReLU-43          [-1, 128, 16, 16]               0
#            Conv2d-44          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-45          [-1, 128, 16, 16]             256
#              ReLU-46          [-1, 128, 16, 16]               0
#        BasicBlock-47          [-1, 128, 16, 16]               0
#            Conv2d-48          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-49          [-1, 128, 16, 16]             256
#              ReLU-50          [-1, 128, 16, 16]               0
#            Conv2d-51          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-52          [-1, 128, 16, 16]             256
#              ReLU-53          [-1, 128, 16, 16]               0
#        BasicBlock-54          [-1, 128, 16, 16]               0
#            Conv2d-55            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-56            [-1, 256, 8, 8]             512
#              ReLU-57            [-1, 256, 8, 8]               0
#            Conv2d-58            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-59            [-1, 256, 8, 8]             512
#            Conv2d-60            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-61            [-1, 256, 8, 8]             512
#              ReLU-62            [-1, 256, 8, 8]               0
#        BasicBlock-63            [-1, 256, 8, 8]               0
#            Conv2d-64            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-65            [-1, 256, 8, 8]             512
#              ReLU-66            [-1, 256, 8, 8]               0
#            Conv2d-67            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-68            [-1, 256, 8, 8]             512
#              ReLU-69            [-1, 256, 8, 8]               0
#        BasicBlock-70            [-1, 256, 8, 8]               0
#            Conv2d-71            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-72            [-1, 256, 8, 8]             512
#              ReLU-73            [-1, 256, 8, 8]               0
#            Conv2d-74            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-75            [-1, 256, 8, 8]             512
#              ReLU-76            [-1, 256, 8, 8]               0
#        BasicBlock-77            [-1, 256, 8, 8]               0
#            Conv2d-78            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-79            [-1, 256, 8, 8]             512
#              ReLU-80            [-1, 256, 8, 8]               0
#            Conv2d-81            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-82            [-1, 256, 8, 8]             512
#              ReLU-83            [-1, 256, 8, 8]               0
#        BasicBlock-84            [-1, 256, 8, 8]               0
#            Conv2d-85            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-86            [-1, 256, 8, 8]             512
#              ReLU-87            [-1, 256, 8, 8]               0
#            Conv2d-88            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-89            [-1, 256, 8, 8]             512
#              ReLU-90            [-1, 256, 8, 8]               0
#        BasicBlock-91            [-1, 256, 8, 8]               0
#            Conv2d-92            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-93            [-1, 256, 8, 8]             512
#              ReLU-94            [-1, 256, 8, 8]               0
#            Conv2d-95            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-96            [-1, 256, 8, 8]             512
#              ReLU-97            [-1, 256, 8, 8]               0
#        BasicBlock-98            [-1, 256, 8, 8]               0
#            Conv2d-99            [-1, 512, 4, 4]       1,179,648
#      BatchNorm2d-100            [-1, 512, 4, 4]           1,024
#             ReLU-101            [-1, 512, 4, 4]               0
#           Conv2d-102            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-103            [-1, 512, 4, 4]           1,024
#           Conv2d-104            [-1, 512, 4, 4]         131,072
#      BatchNorm2d-105            [-1, 512, 4, 4]           1,024
#             ReLU-106            [-1, 512, 4, 4]               0
#       BasicBlock-107            [-1, 512, 4, 4]               0
#           Conv2d-108            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-109            [-1, 512, 4, 4]           1,024
#             ReLU-110            [-1, 512, 4, 4]               0
#           Conv2d-111            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-112            [-1, 512, 4, 4]           1,024
#             ReLU-113            [-1, 512, 4, 4]               0
#       BasicBlock-114            [-1, 512, 4, 4]               0
#           Conv2d-115            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-116            [-1, 512, 4, 4]           1,024
#             ReLU-117            [-1, 512, 4, 4]               0
#           Conv2d-118            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-119            [-1, 512, 4, 4]           1,024
#             ReLU-120            [-1, 512, 4, 4]               0
#       BasicBlock-121            [-1, 512, 4, 4]               0
# AdaptiveAvgPool2d-122            [-1, 512, 1, 1]               0
#           Linear-123                 [-1, 2470]       1,267,110
#            Model-124   [[-1, 2470], [-1, 2470]]               0
# ================================================================
# Total params: 22,542,566
# Trainable params: 22,542,566
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 20.09
# Params size (MB): 85.99
# Estimated Total Size (MB): 106.09
# ----------------------------------------------------------------

# %%
def compute_accuracy(model, data_loader, device):
    model.eval()
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100


def train_model(model, data_loader, optimizer, num_epochs,batch_size, device,metric_func, random_seed = 7):
    # Manual seed for deterministic data loader
    torch.manual_seed(random_seed)
    
    loss_list = []
    valid_acc_list = []
    best_valid_acc = 0
    
    for epoch in range(num_epochs):
        start = time.time()
        # set training mode
        model.train() 
        for batch_idx, (features, targets) in enumerate(data_loader["train"]):
            features = features.to(device)
            targets = targets.to(device)


            ## forward pass
            logits, probas = model(features)
            loss = F.cross_entropy(logits,targets)
            
            _, predicted_labels = torch.max(probas, 1)
            correct_pred = (predicted_labels == targets).sum()
            train_acc = correct_pred.float() / target.size(0) * 100
            
            # backward pass
            # clear the gradients of all tensors being optimized
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            ### Login
            loss_list.append(loss.item())
            
            if batch_idx % 100 == 0:
                
                print('Epoch: {0:03d}/{1:03d} | Batch {2:03d}/{3:03d} | Loss: {4:.3f} | Acc: {5:.3f} % \n'.format(
                    epoch+1, num_epochs, batch_idx, 
                         len(train_dataset)//batch_size, loss, train_acc))
                
                with open("train_log", "a") as f:
                    f.write('Epoch: {0:03d}/{1:03d} | Batch {2:03d}/{3:03d} | Loss: {4:.3f} | Acc: {5:.3f} \n'.format(
                    epoch+1, num_epochs, batch_idx, 
                         len(train_dataset)//batch_size, loss, train_acc))
        
        end = time.time()
        with torch.set_grad_enabled(False):
            
            valid_acc = metric_func(model, data_loader["val"], device)
            
            print('Epoch: {0:03d}/{1:03d} | val acc: {2:.3f} % | time: {3:.3f} s'.format(
                  epoch+1, num_epochs, valid_acc, end-start))
            
            with open("train_log","a") as f:
                f.write('Epoch: {0:03d}/{1:03d} | val acc: {2:.3f} % | time: {3:.3f} s \n'.format(
                  epoch+1, num_epochs, valid_acc, end-start))
            
            if not os.path.exists("../models/tyc_model_checkpoint"):
                os.mkdir("../models/tyc_model_checkpoint")
            
            if best_valid_acc < valid_acc:
                best_valid_acc = valid_acc
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'valid_roc': valid_acc,
                    'optimizer_state_dict': optimizer.state_dict(),
                }, "../models/tyc_model_checkpoint/best_model.pt")
            
            valid_acc_list.append(valid_acc)
        
        scheduler.step(valid_acc)
            
    checkpoint = torch.load("../models/tyc_model_checkpoint/best_model.pt")
    model.load_state_dict(checkpoint["model_state_dict"])
            
    return model, loss_list, valid_acc_list

# %%
model, loss_list, valid_acc_list = train_model(model, 
            dataset_loader, 
            optimizer, 
            NUM_EPOCHS, 
            device = DEVICE, 
            batch_size = BATCH_SIZE,
            metric_func = compute_accuracy)
# Out:
# Epoch: 001/020 | Batch 000/1134 | Loss: 9.011 | Acc: 0.000 %
#
# Epoch: 001/020 | Batch 100/1134 | Loss: 8.584 | Acc: 6.250 %

# %%
plt.plot(loss_list, label='Minibatch cost')
plt.plot(np.convolve(loss_list, 
                     np.ones(30,)/30, mode='valid'), 
         label='Running average')

plt.ylabel('Cross Entropy')
plt.xlabel('Iteration')
plt.legend()
plt.show()

# %%
plt.plot(np.arange(1, NUM_EPOCHS+1), valid_acc_list, label='Validation')

plt.xlabel('Epoch')
plt.ylabel('ROC')
plt.legend()
plt.show()

# %%
test_transforms = A.Compose([
                        A.Resize(32,32),
#                         A.ToGray(),
                        A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
                        ToTensor()
                    ])


class TycOCRTestDataset(Dataset):
      
    def __init__(self, root, char2index, transforms = None):

        self.samples = []
        self.labels = []        
        self.char2index = char2index
        
        self.transforms = transforms

        for direc in root.glob("*"):
            if direc.is_dir():
                source = direc / "0"
                target = direc / "1"

                target_set = set()

                for s_char in source.glob("*.png"):
                    char = s_char.name[0]
                    self.samples.append(s_char)
                    self.labels.append( self.char2index.get(char,-1) )
                      
                for t_char in target.glob("*.png"):
                    char = t_char.name[0]
                    self.samples.append(t_char)
                    self.labels.append(self.char2index.get(char,-1))
                    

    def __getitem__(self, index):

        img = self.samples[index]
        target = self.labels[index]        
        img = cv2.imread(str(img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
        img = self.transforms(image = img)["image"]

        return img,torch.tensor(target)
    
    def __len__(self):
        return len(self.samples)
    
    
test_dataset = TycOCRTestDataset(Path("test_data"), dataset.char2index, transforms = test_transforms )
test_dataloader = DataLoader(dataset = test_dataset,
                             batch_size=32,
                             num_workers=4,
                             shuffle=True)

# %%
image, target = next(iter(test_dataloader))
show_batch(image.permute([0,2,3,1]), target.numpy(), (4,4))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.eval()
all_preds = []
all_targets = []

for i, (features,targets) in enumerate(test_dataloader):
    features = features.to(DEVICE)
    logits,probas = model(features)
    _, predicted_labels = torch.max(probas, 1)
    all_preds += predicted_labels.tolist()
    all_targets += targets.tolist()

# %%
np.mean(np.array(all_preds) == np.array(all_targets))
# Out:
# 0.4638888888888889
